# %% [markdown]
# # Lab 4- Object Oriented Programming
# # Mariah Noelle Cornelio
# ###
#
# For all of the exercises below, make sure you provide tests of your solutions.

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
## DISCLAIMER BEFORE RUNNING ##

# My code is a little long because each question builds up on the last so it was a lot of
# copy and pasting my previous code so I could see what I needed to change and what I needed
# to keep. I hashtagged my old code instead of deleting it so I could see what my mistakes were.
# I tried my best to annotate my code when necessary so it would be easier to grade/read. 

## THANK YOU! :) ##

# %%
class counter:
    def __init__(self, max_val):
        self.value=0
        self.max_val=max_val

    def add(self):
        if self.value<self.max_val:
            self.value=self.value+1
            print("The current count is: ", self.value)
        else:
            print("\nInvalid. Cannot increment past the maximum value. Try resetting or add appropriately.")

    def reset(self):
        self.value=0
        print("\nCannot increment past maximum value. Counter reset. The current count is: ", self.value)

# %%
# Testing my solution
max_val=10 # My max value is 10
counter_test1=counter(max_val)

for number in range(15): # Since my max value is 10, it will not work for numbers more than 10
    if number<max_val:
        counter_test1.add()
    else:
        counter_test1.reset()
# Out:
# The current count is:  1
# The current count is:  2
# The current count is:  3
# The current count is:  4
# The current count is:  5
# The current count is:  6
# The current count is:  7
# The current count is:  8
# The current count is:  9
# The current count is:  10
#
# Cannot increment past maximum value. Counter reset. The current count is:  0
#
# Cannot increment past maximum value. Counter reset. The current count is:  0
#
# Cannot increment past maximum value. Counter reset. The current count is:  0
#
# Cannot increment past maximum value. Counter reset. The current count is:  0
#
# Cannot increment past maximum value. Counter reset. The current count is:  0

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
class counter:
    def __init__(self, max_val):
        self.__value=0
        self.__max_val=max_val

    def __add(self):
        if self.__value<self.__max_val:
            self.__value=self.__value+1
            print("The current count is:", self.__value)
        else:
            print("Invalid. Cannot increment past the maximum value. Try resetting or adding appropriately.")

    def add(self):
        self.__add()

    def reset(self):
        self.__value=0
        print("\nCannot increment past maximum value. Counter reset. The current count is:", self.__value)

    def check_value(self):
        return self.__value

    def check_max_val(self):
        return self.__max_val

    def is_at_max(self):
        # return self.__value==self.__max_val
        if self.__value==self.__max_val:
            return "Yes, it reached the maximum value."
        else:
            return "No, not yet at maximum value."

# %%
# Testing my solution

max_value=10
counter_test2=counter(max_value)

for number in range(15):
    counter_test2.add()
    
counter_test2.reset()

print(" ")
print("Current value: ", counter_test2.check_value())
print("What is the maximum value ?", counter_test2.check_max_val())
print("Is the counter at maximum? ", counter_test2.is_at_max())
# Out:
# The current count is: 1
# The current count is: 2
# The current count is: 3
# The current count is: 4
# The current count is: 5
# The current count is: 6
# The current count is: 7
# The current count is: 8
# The current count is: 9
# The current count is: 10
# Invalid. Cannot increment past the maximum value. Try resetting or adding appropriately.
# Invalid. Cannot increment past the maximum value. Try resetting or adding appropriately.
# Invalid. Cannot increment past the maximum value. Try resetting or adding appropriately.
# Invalid. Cannot increment past the maximum value. Try resetting or adding appropriately.
# Invalid. Cannot increment past the maximum value. Try resetting or adding appropriately.
#
# Cannot increment past maximum value. Counter reset. The current count is: 0
#
# Current value:  0
# What is the maximum value ? 10
# Is the counter at maximum?  No, not yet at maximum value.

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class rectangle:
    def __init__(self, length, width, x, y):
        self.__length=length
        self.__width=width
        self.__x=x
        self.__y=y

    def area(self): # l x w
        return self.__length*self.__width

    def perimeter(self): # 2l + 2w
        return (2*self.__length)+(2*self.__width)
    
    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

# %%
# Testing my solution
rectangle_test1=rectangle(length=12, width=30, x=6, y=96)

print("Features of your rectangle:")
print("-----------------------------\n")
print("Rectangle length:", rectangle_test1.get_length())
print("Rectangle width:", rectangle_test1.get_width())
print("X coordinate:", rectangle_test1.get_x())
print("Y coordinate:", rectangle_test1.get_y())
print("Area of rectangle:", rectangle_test1.area())
print("Perimeter of rectangle:", rectangle_test1.perimeter())
# Out:
# Features of your rectangle:
# -----------------------------
#
# Rectangle length: 12
# Rectangle width: 30
# X coordinate: 6
# Y coordinate: 96
# Area of rectangle: 360
# Perimeter of rectangle: 84

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and perimeter of the circle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class circle:
    def __init__(self, radius, x, y):
        self.__radius=radius
        self.__x=x
        self.__y=y

    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def area(self): # pi r squared
        pi=3.14159
        return (pi*self.__radius)**2

    def circumference(self): #2 pi r
        pi=3.14159
        return 2*pi* self.__radius

# %%
# Testing my solution
circle_test1=circle(radius=6, x=2, y=4)

print("Features of your circle:")
print("-----------------------------\n")
print("Radius:", circle_test1.get_radius())
print("X Coordinate:", circle_test1.get_x())
print("Y Coordinate:", circle_test1.get_y())
print("Area:", circle_test1.area())
print("Perimeter:", circle_test1.circumference())
# Out:
# Features of your circle:
# -----------------------------
#
# Radius: 6
# X Coordinate: 2
# Y Coordinate: 4
# Area: 355.3051582115999
# Perimeter: 37.699079999999995

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as not implemented functions (virtual). Re-implement those classes to inherit from the base class and overload the functions accordingly.

# %%
class shape:
    def __init__(self, x, y):
        self.__x=x
        self.__y=y

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def area(self):
        raise NotImplementedError

    def perimeter(self):
        raise NotImplementedError
        
    def circumference(self):
        raise NotImplementedError

class rectangle(shape):
    def __init__(self, length, width, x, y):
        shape.__init__(self, x, y)
        self.__length=length
        self.__width=width

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def area(self): # l x w
        return self.__length*self.__width

    def perimeter(self): # 2l + 2w
        return (2*self.__length)+(2*self.__width)

class circle(shape):
    def __init__(self, radius, x, y):
        shape.__init__(self, x, y)
        self.__radius=radius

    def get_radius(self):
        return self.__radius

    def area(self): # pi r squared
        pi=3.14159
        return (pi*self.__radius)**2

    def circumference(self): # 2 pi r
        pi=3.14159
        return 2*pi*self.__radius

# %%
# Testing my solution - using shape class first
shape_test1=shape(x=3, y=6)

print("Features of your shape:")
print("-----------------------------\n")
print("X coordinate:", shape_test1.get_x())
print("Y coordinate:", shape_test1.get_y())
print("Area:", shape_test1.area())
print("Perimeter:", shape_test1.perimeter())

# NotImplementedError comes up because a shape needs to be specified...
# Out:
# Features of your shape:
# -----------------------------
#
# X coordinate: 3
# Y coordinate: 6
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[132], line 8
#       6 print("X coordinate:", shape_test1.get_x())
#       7 print("Y coordinate:", shape_test1.get_y())
# ----> 8 print("Area:", shape_test1.area())
#       9 print("Perimeter:", shape_test1.perimeter())
#
# Cell In[131], line 13, in shape.area(self)
#      12 def area(self):
# ---> 13     raise NotImplementedError
#
# NotImplementedError:

# %%
# Testing my solution - using specific shapes
rectangle_test2=rectangle(length=19, width=12, x=4, y=10)
circle_test2=circle(radius=5, x=8, y=12)

print("Features of your rectangle:")
print("-----------------------------")
print("X coordinate:", rectangle_test2.get_x())
print("Y coordinate:", rectangle_test2.get_y())
print("Area:", rectangle_test2.area())
print("Perimeter:", rectangle_test2.perimeter())

print("\nFeatures of your circle:")
print("-----------------------------")
print("X coordinate:", circle_test2.get_x())
print("Y coordinate:", circle_test2.get_y())
print("Area:", circle_test2.area())
print("Perimeter:", circle_test2.circumference())
# Out:
# Features of your rectangle:
# -----------------------------
# X coordinate: 4
# Y coordinate: 10
# Area: 228
# Perimeter: 62
#
# Features of your circle:
# -----------------------------
# X coordinate: 8
# Y coordinate: 12
# Area: 246.7396932025
# Perimeter: 31.4159

# %% [markdown]
# 6. Implement an analogous triangle class.

# %%
class triangle(shape):
    def __init__(self, base, height, x, y):
        shape.__init__(self, x, y)
        self.__base=base
        self.__height=height

    def get_base(self):
        return self.__base

    def get_height(self):
        return self.__height

    def area(self): # 1/2 * b * h 
        return 0.5*self.__base*self.__height

    def perimeter(self): # side1 + side2 + side3 but since only given b and h, use this formula
        return self.__base+self.__height+(self.__base**2 + self.__height**2)**0.5

# %%
# Testing my solution
triangle_test1=triangle(base=6, height=2, x=4, y=8)

print("Features of your triangle:")
print("-----------------------------\n")
print("X coordinate:", triangle_test1.get_x())
print("Y coordinate:", triangle_test1.get_y())
print("Base:", triangle_test1.get_base())
print("Height:", triangle_test1.get_height())
print("Area:", triangle_test1.area())
print("Perimeter:", triangle_test1.perimeter())
# Out:
# Features of your triangle:
# -----------------------------
#
# X coordinate: 4
# Y coordinate: 8
# Base: 6
# Height: 2
# Area: 6.0
# Perimeter: 14.32455532033676

# %% [markdown]
# 7. Add a function to the object classes that tests if a given set of $x$ and $y$ coordinates are inside of the object.

# %%
class shape:
    def __init__(self, x, y):
        self.__x=x
        self.__y=y
    def get_x(self):
        return self.__x
    def get_y(self):
        return self.__y
    def area(self):
        raise NotImplementedError
    def perimeter(self):
        raise NotImplementedError
    def circumference(self):
        raise NotImplementedError
    def point_inside(self, x_point_test, y_point_test):
        raise NotImplementedError
    
class rectangle(shape):
    def __init__(self, length, width, x, y):
        shape.__init__(self, x, y)
        self.__length=length
        self.__width=width
    def get_length(self):
        return self.__length
    def get_width(self):
        return self.__width
    def area(self): # l x w
        return self.__length*self.__width
    def perimeter(self): # 2l + 2w
        return (2*self.__length)+(2*self.__width)
    def point_inside(self, x_point_test, y_point_test):
        if (self.get_x() <= x_point_test <= (self.get_x()+self.get_length()) and self.get_y() <= y_point_test <= (self.get_y() + self.get_width())):
            return "Yes, this point is in your shape."
        else:
            return "No, this point is not in your shape."


class circle(shape):
    def __init__(self, radius, x, y):
        shape.__init__(self, x, y)
        self.__radius=radius
    def get_radius(self):
        return self.__radius
    def area(self): # pi r squared
        pi=3.14159
        return (pi*self.__radius)**2
    def circumference(self): # 2 pi r
        pi=3.14159
        return 2*pi*self.__radius
    def point_inside(self, x_point_test, y_point_test):
        # If the distance is less than radius then that means the point is inside the circle
        distance=((self.get_x() - x_point_test)**2 + (self.get_y() - y_point_test)**2)**0.5
        if distance <= self.__radius:
            return "Yes, this point is in your shape."
        else: 
            return "No, this point is not in your shape."

class triangle(shape):
    def __init__(self, base, height, x, y):
        shape.__init__(self, x, y)
        self.__base=base
        self.__height=height
    def get_base(self):
        return self.__base
    def get_height(self):
        return self.__height
    def area(self): # 1/2 * b * h 
        return 0.5*self.__base*self.__height
    def perimeter(self): # side1 + side2 + side3 but since only given b and h, use this formula
        return self.__base+self.__height+(self.__base**2 + self.__height**2)**0.5

    def point_inside(self, x_point_test, y_point_test): # Use barycentric coordinats
        s=(self.get_y()+self.__height-y_point_test)/self.__height
        t=(x_point_test-self.get_x())/self.__base
        if 0<=s<=1 and 0<=t<=1 and s+t<= 1:
            return "Yes, this point is in your shape."
        else: 
            return "No, this point is not in your shape."

# %%
# Testing my solution
rectangle_test3=rectangle(length=5, width=3, x=2, y=4)
circle_test3=circle(radius=4, x=90, y=3)
triangle_test2=triangle(base=15, height=-4, x=1, y=2)

test_point=(4, 5)

print("Testing if test points are in your rectangle:")
print("-----------------------------")
print(f"{test_point}:", rectangle_test3.point_inside(*test_point))

print("\nTesting if test points are in your circle:")
print("-----------------------------")
print(f"{test_point}:", circle_test3.point_inside(*test_point))

print("\nTesting if test points are in your triangle:")
print("-----------------------------")
print(f"{test_point}:", triangle_test2.point_inside(*test_point))
# Out:
# Testing if test points are in your rectangle:
# -----------------------------
# (4, 5): Yes, this point is in your shape.
#
# Testing if test points are in your circle:
# -----------------------------
# (4, 5): No, this point is not in your shape.
#
# Testing if test points are in your triangle:
# -----------------------------
# (4, 5): No, this point is not in your shape.

# %% [markdown]
# 8. Add a function to the object classes that return a list of up to 16 pairs of  $x$ and $y$ points on the parameter of the object.

# %%
import math

class shape:
    def __init__(self, x, y):
        self.__x=x
        self.__y=y
    def get_x(self):
        return self.__x
    def get_y(self):
        return self.__y
    def area(self):
        raise NotImplementedError
    def perimeter(self):
        raise NotImplementedError
    def circumference(self):
        raise NotImplementedError
    def point_inside(self, x_point_test, y_point_test):
        raise NotImplementedError
    def parameter_points(self, points=16):
        raise NotImplementedError

class rectangle(shape):
    def __init__(self, length, width, x, y):
        shape.__init__(self, x, y)
        self.__length=length
        self.__width=width
    def get_length(self):
        return self.__length
    def get_width(self):
        return self.__width
    def area(self): # l x w
        return self.__length*self.__width
    def perimeter(self): # 2l + 2w
        return (2*self.__length)+(2*self.__width)
    def point_inside(self, x_point_test, y_point_test):
        if (self.get_x() <= x_point_test <= (self.get_x()+self.get_length()) and self.get_y() <= y_point_test <= (self.get_y() + self.get_width())):
            return "Yes, this point is in your shape."
        else:
            return "No, this point is not in your shape."
    def parameter_points(self, points=16):
        points_16=[]
        for i in range(points):
            p=i/(points-1)
            x=(self.get_x())+(p*self.get_length())
            y=self.get_y()
            points_16.append((x, y))
        return points_16


class circle(shape):
    def __init__(self, radius, x, y):
        shape.__init__(self, x, y)
        self.__radius=radius
    def get_radius(self):
        return self.__radius
    def area(self): # pi r squared
        pi=3.14159
        return (pi*self.__radius)**2
    def circumference(self): # 2 pi r
        pi=3.14159
        return 2*pi*self.__radius
    def point_inside(self, x_point_test, y_point_test):
        # If the distance is less than radius then that means the point is inside the circle
        distance=((self.get_x() - x_point_test)**2 + (self.get_y() - y_point_test)**2)**0.5
        if distance <= self.__radius:
            return "Yes, this point is in your shape."
        else: 
            return "No, this point is not in your shape."
    def parameter_points(self, points=16):
        points_16=[]
        for i in range(points):
            pi=3.14159
            angle=i*(2*pi)/points # Converts to radians first
            x=self.get_x() + self.get_radius()*math.cos(angle)
            y=self.get_y() + self.get_radius()*math.sin(angle)
            points_16.append((x, y))
        return points_16


class triangle(shape):
    def __init__(self, base, height, x, y):
        shape.__init__(self, x, y)
        self.__base=base
        self.__height=height
    def get_base(self):
        return self.__base
    def get_height(self):
        return self.__height
    def area(self): # 1/2 * b * h 
        return 0.5*self.__base*self.__height
    def perimeter(self): # side1 + side2 + side3 but since only given b and h, use this formula
        return self.__base+self.__height+(self.__base**2 + self.__height**2)**0.5
    def parameter_points(self, points=16):
        points_16=[]
        for i in range(points):
            p=i/(points-1)
            x=self.get_x() + p*self.__base
            y=self.get_y()
            points_16.append((x, y))
        return points_16

# %%
# Testing my solution
rectangle_test4=rectangle(length=5, width=4, x=1, y=10)
circle_test4=circle(radius=6, x=2, y=3)
triangle_test3=triangle(base=9, height=4, x=4, y=1)

print("Your 16 rectangle parameter points:")
print("-----------------------------")
print(rectangle_test4.parameter_points())

print("\nYour 16 circle parameter points:")
print("-----------------------------")
print(circle_test4.parameter_points())

print("\nYour 16 triangle parameter points:")
print("-----------------------------")
print(triangle_test3.parameter_points())
# Out:
# Your 16 rectangle parameter points:
# -----------------------------
# [(1.0, 10), (1.3333333333333333, 10), (1.6666666666666665, 10), (2.0, 10), (2.333333333333333, 10), (2.6666666666666665, 10), (3.0, 10), (3.3333333333333335, 10), (3.6666666666666665, 10), (4.0, 10), (4.333333333333333, 10), (4.666666666666666, 10), (5.0, 10), (5.333333333333334, 10), (5.666666666666667, 10), (6.0, 10)]
#
# Your 16 circle parameter points:
# -----------------------------
# [(8.0, 3.0), (7.543277956681053, 5.296098755492439), (6.242643501675357, 7.242637872561345), (4.296106110283322, 8.543274910224063), (2.00000796076938, 8.999999999994719), (-0.29609140069751483, 8.543281003128286), (-2.2426322434398642, 7.242649130781902), (-3.5432718637573144, 5.296113465070163), (-3.9999999999788756, 3.0000159215387603), (-3.5432840495657585, 0.7039159541014519), (-2.242654759880975, -1.2426266143109164), (-0.296120819852959, -2.543268817280808), (1.9999761176918571, -2.999999999952469), (4.296076691095537, -2.543287095993475), (6.242620985174496, -1.242660388972583), (7.543265770794543, 0.7038718253682816)]
#
# Your 16 triangle parameter points:
# -----------------------------
# [(4.0, 1), (4.6, 1), (5.2, 1), (5.8, 1), (6.4, 1), (7.0, 1), (7.6, 1), (8.2, 1), (8.8, 1), (9.399999999999999, 1), (10.0, 1), (10.6, 1), (11.2, 1), (11.8, 1), (12.4, 1), (13.0, 1)]

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
class shape:
    def __init__(self, x, y):
        self.__x=x
        self.__y=y
    def get_x(self):
        return self.__x
    def get_y(self):
        return self.__y
    def area(self):
        raise NotImplementedError
    def perimeter(self):
        raise NotImplementedError
    def circumference(self):
        raise NotImplementedError
    def point_inside(self, x_point_test, y_point_test):
        raise NotImplementedError
    def parameter_points(self, points=16):
        raise NotImplementedError
    def check_overlap(self, shape2):
        x1=self.__x
        y1=self.__y
        x2=shape2.get_x()
        y2=shape2.get_y()
        if ((x1<x2+shape2.perimeter() and x1+self.perimeter()>=x2 and y1<y2+shape2.perimeter() and y1+self.perimeter()>=y2)):
            return True
        else:
            return False
        
class rectangle(shape):
    def __init__(self, length, width, x, y):
        shape.__init__(self, x, y)
        self.__length=length
        self.__width=width
    def get_length(self):
        return self.__length
    def get_width(self):
        return self.__width
    def area(self): # l x w
        return self.__length*self.__width
    def perimeter(self): # 2l + 2w
        return (2*self.__length)+(2*self.__width)
    def point_inside(self, x_point_test, y_point_test):
        if (self.get_x() <= x_point_test <= (self.get_x()+self.get_length()) and self.get_y() <= y_point_test <= (self.get_y() + self.get_width())):
            return "Yes, this point is in your shape."
        else:
            return "No, this point is not in your shape."
    def parameter_points(self, points=16):
        points_16=[]
        for i in range(points):
            p=i/(points-1)
            x=(self.get_x())+(p*self.get_length())
            y=self.get_y()
            points_16.append((x, y))
        return points_16
    
class circle(shape):
    def __init__(self, radius, x, y):
        shape.__init__(self, x, y)
        self.__radius=radius
    def get_radius(self):
        return self.__radius
    def area(self): # pi r squared
        pi=3.14159
        return (pi*self.__radius)**2
    def circumference(self): # 2 pi r
        pi=3.14159
        return 2*pi*self.__radius
    def point_inside(self, x_point_test, y_point_test):
        # If the distance is less than radius then that means the point is inside the circle
        distance=((self.get_x() - x_point_test)**2 + (self.get_y() - y_point_test)**2)**0.5
        if distance <= self.__radius:
            return "Yes, this point is in your shape."
        else: 
            return "No, this point is not in your shape."
    def parameter_points(self, points=16):
        points_16=[]
        for i in range(points):
            pi=3.14159
            angle=i*(2*pi)/points # Converts to radians first
            x=self.get_x() + self.get_radius()*math.cos(angle)
            y=self.get_y() + self.get_radius()*math.sin(angle)
            points_16.append((x, y))
        return points_16
    
class triangle(shape):
    def __init__(self, base, height, x, y):
        shape.__init__(self, x, y)
        self.__base=base
        self.__height=height
    def get_base(self):
        return self.__base
    def get_height(self):
        return self.__height
    def area(self): # 1/2 * b * h 
        return 0.5*self.__base*self.__height
    def perimeter(self): # side1 + side2 + side3 but since only given b and h, use this formula
        return self.__base+self.__height+(self.__base**2 + self.__height**2)**0.5
    def parameter_points(self, points=16):
        points_16=[]
        for i in range(points):
            p=i/(points-1)
            x=self.get_x() + p*self.__base
            y=self.get_y()
            points_16.append((x, y))
        return points_16

# %%
# Testing my solution
rectangle_test5=rectangle(length=5, width=3, x=6, y=4)
rectangle_test6=rectangle(length=4, width=5, x=3, y=3)
triangle_test4=triangle(base=2, height=-3, x=4, y=1)

print("Does rectangle_test5 overlap with rectangle_test6?", rectangle_test5.check_overlap(rectangle_test6))
print("Does rectangle_test5 overlap with triangle_test4?", rectangle_test5.check_overlap(triangle_test4))
# Out:
# Does rectangle_test5 overlap with rectangle_test6? True
# Does rectangle_test5 overlap with triangle_test4? False

# %% [markdown]
# 10. Copy the `Canvas` class from lecture to in a python file creating a `paint` module. Copy your classes from above into the module and implement paint functions. Implement a `CompoundShape` class. Create a simple drawing demonstrating that all of your classes are working.

# %%
# Canvas class copied from lecture
class Canvas: 
    def __init__(self, width, height):
        self.width = width
        self.height = height
        self.data = [[' '] * width for i in range(height)]

    def set_pixel(self, row, col, char='*'):
        self.data[row][col] = char

    def get_pixel(self, row, col):
        return self.data[row][col]
    
    def clear_canvas(self):
        self.data = [[' '] * self.width for i in range(self.height)]
    
    def v_line(self, x, y, w, **kargs):
        for i in range(x,x+w):
            self.set_pixel(i,y, **kargs)

    def h_line(self, x, y, h, **kargs):
        for i in range(y,y+h):
            self.set_pixel(x,i, **kargs)
            
    def line(self, x1, y1, x2, y2, **kargs):
        slope = (y2-y1) / (x2-x1)
        for y in range(y1,y2):
            x= int(slope * y)
            self.set_pixel(x,y, **kargs)
            
    def display(self):
        print("\n".join(["".join(row) for row in self.data]))
        
# My classes
class shape:
    def __init__(self, x, y):
        self.__x=x
        self.__y=y
    def get_x(self):
        return self.__x
    def get_y(self):
        return self.__y
    def area(self):
        raise NotImplementedError
    def perimeter(self):
        raise NotImplementedError
    def circumference(self):
        raise NotImplementedError
    def point_inside(self, x_point_test, y_point_test):
        raise NotImplementedError
    def parameter_points(self, points=16):
        raise NotImplementedError
    def check_overlap(self, shape2):
        x1=self.__x
        y1=self.__y
        x2=shape2.get_x()
        y2=shape2.get_y()
        if ((x1<x2+shape2.perimeter() and x1+self.perimeter()>=x2 and y1<y2+shape2.perimeter() and y1+self.perimeter()>=y2)):
            return True
        else:
            return False
    # Draw function
    def draw(self, canvas, char="*"):
        canvas.set_pixel(self.get_y(), self.get_x(), char)
        
class rectangle(shape):
    def __init__(self, length, width, x, y):
        shape.__init__(self, x, y)
        self.__length=length
        self.__width=width
    def get_length(self):
        return self.__length
    def get_width(self):
        return self.__width
    def area(self): # l x w
        return self.__length*self.__width
    def perimeter(self): # 2l + 2w
        return (2*self.__length)+(2*self.__width)
    def point_inside(self, x_point_test, y_point_test):
        if (self.get_x() <= x_point_test <= (self.get_x()+self.get_length()) and self.get_y() <= y_point_test <= (self.get_y() + self.get_width())):
            return "Yes, this point is in your shape."
        else:
            return "No, this point is not in your shape."
    def parameter_points(self, points=16):
        points_16=[]
        for i in range(points):
            p=i/(points-1)
            x=(self.get_x())+(p*self.get_length())
            y=self.get_y()
            points_16.append((x, y))
        return points_16
    # Draw function
    def draw(self, canvas, char="*"):
        x=self.get_x()
        y=self.get_y()
        length=self.__length
        width=self.__width
        for i in range(x, x+length):
            for j in range(y, y+width):
                canvas.set_pixel(j, i, char)
    
class circle(shape):
    def __init__(self, radius, x, y):
        shape.__init__(self, x, y)
        self.__radius=radius
    def get_radius(self):
        return self.__radius
    def area(self): # pi r squared
        pi=3.14159
        return (pi*self.__radius)**2
    def circumference(self): # 2 pi r
        pi=3.14159
        return 2*pi*self.__radius
    def point_inside(self, x_point_test, y_point_test):
        # If the distance is less than radius then that means the point is inside the circle
        distance=((self.get_x() - x_point_test)**2 + (self.get_y() - y_point_test)**2)**0.5
        if distance <= self.__radius:
            return "Yes, this point is in your shape."
        else: 
            return "No, this point is not in your shape."
    def parameter_points(self, points=16):
        points_16=[]
        for i in range(points):
            pi=3.14159
            angle=i*(2*pi)/points # Converts to radians first
            x=self.get_x() + self.get_radius()*math.cos(angle)
            y=self.get_y() + self.get_radius()*math.sin(angle)
            points_16.append((x, y))
        return points_16
    # Draw function
    def draw(self, canvas, char="*"):
        x=self.get_x()
        y=self.get_y()
        radius=self.__radius
        for i in range(x-radius, x+radius+1):
            for j in range(y-radius, y+radius+1):
                if (x-i)**2 + (y-j)**2 <= radius**2:
                    canvas.set_pixel(j, i, char)
    
class triangle(shape):
    def __init__(self, base, height, x, y):
        shape.__init__(self, x, y)
        self.__base=base
        self.__height=height
    def get_base(self):
        return self.__base
    def get_height(self):
        return self.__height
    def area(self): # 1/2 * b * h 
        return 0.5*self.__base*self.__height
    def perimeter(self): # side1 + side2 + side3 but since only given b and h, use this formula
        return self.__base+self.__height+(self.__base**2 + self.__height**2)**0.5
    def parameter_points(self, points=16):
        points_16=[]
        for i in range(points):
            p=i/(points-1)
            x=self.get_x() + p*self.__base
            y=self.get_y()
            points_16.append((x, y))
        return points_16
    # Draw function
    #def draw(self, canvas, char="*"): # This code did not draw in a triangle
        #x=self.get_x()
        #y=self.get_y()
        #base=self.__base
        #height=self.__height
        #for i in range(x, x+base):
            #for j in range(y, y+height):
                #if i<=x+(base-1)-j/height*base and i >= x+j/height*base:
                    #canvas.set_pixel(j, i, char)
    def draw(self, canvas, char="*"):
        x=self.get_x()
        y=self.get_y()
        base=self.__base
        height=self.__height
        for i in range(x, x+base):
            for j in range(y, y+height):
                if i<=x+(base-1)-(j-y)/height*base and i>=x+(j-y)/height*base:
                    canvas.set_pixel(j, i, char)

    
# My CompoundShape class
class CompoundShape(shape):
    def __init__(self, x, y):
        shape.__init__(self,x, y)
        self.subshapes=[]

    def add_subshape(self, subshape):
        self.subshapes.append(subshape)

    def draw(self, canvas, char="*"):
        for subshape in self.subshapes:
            subshape.draw(canvas, char)

# %%
# Testing my solution - PLAY AROUND WITH THIS - this is without the compound shape feature
canvas_test1=Canvas(width=20, height=10)

rectangle1=rectangle(length=6, width=3, x=0, y=0)
rectangle2=rectangle(length=4, width=3, x=8, y=3)
circle1=circle(radius=4, x=15, y=5)
triangle1=triangle(base=6, height=4, x=2, y=8)

canvas_test1.clear_canvas()
rectangle1.draw(canvas_test1) 
rectangle2.draw(canvas_test1, char="~")
circle1.draw(canvas_test1, char="o")
triangle1.draw(canvas_test1, char="^")

canvas_test1.display()
# Out:
# ******
# ******         o
# ******       ooooo
#         ~~~~ooooooo
#         ~~~~ooooooo
#         ~~~ooooooooo
#             ooooooo
#             ooooooo
#   ^^^^^^     ooooo
#     ^^         o

# %%
# Testing my solution - this is with the compound shape feature
canvas_test2=Canvas(width=20, height=10)

rectangle1=rectangle(length=5, width=3, x=0, y=0)
circle1=circle(radius=4, x=15, y=5)
compound_shape=CompoundShape(x=10, y=6)
compound_shape.add_subshape(rectangle1)
compound_shape.add_subshape(circle1)
compound_shape.draw(canvas_test2, char='O')
canvas_test2.display()
# Out:
# OOOOO
# OOOOO          O
# OOOOO        OOOOO
#             OOOOOOO
#             OOOOOOO
#            OOOOOOOOO
#             OOOOOOO
#             OOOOOOO
#              OOOOO
#                O

# %% [markdown]
# 11. Create a `RasterDrawing` class. Demonstrate that you can create a drawing made of several shapes, paint the drawing, modify the drawing, and paint it again.

# %%
class RasterDrawing:
    def __init__(self, width, height):
        self.canvas=Canvas(width, height)
        self.shapes=[]

    def add_shape(self, shape):
        self.shapes.append(shape)

    def paint(self):
        self.canvas.clear_canvas()  # Clear canvas before painting
        for shape in self.shapes:
            shape.draw(self.canvas)
        self.canvas.display()

    def modify_drawing(self, shape_index, new_shape):
        if 0<=shape_index<len(self.shapes):
            old_shape = self.shapes[shape_index]
            # This code will be run if there is a resize() or move() method
            if isinstance(new_shape, shape):
                if hasattr(new_shape, "resize") and callable(getattr(new_shape, "resize")):
                    new_shape.resize()
                if hasattr(new_shape, "move") and callable(getattr(new_shape, "move")):
                    new_shape.move()
                self.shapes[shape_index]=new_shape
            else:
                print("Invalid new shape.")
        else:
            print("Invalid shape index.")
            
# My classes - but now I add methods to modify my shapes
class shape:
    def __init__(self, x, y):
        self.__x=x
        self.__y=y
    def get_x(self):
        return self.__x
    def get_y(self):
        return self.__y
    def area(self):
        raise NotImplementedError
    def perimeter(self):
        raise NotImplementedError
    def circumference(self):
        raise NotImplementedError
    def point_inside(self, x_point_test, y_point_test):
        raise NotImplementedError
    def parameter_points(self, points=16):
        raise NotImplementedError
    def check_overlap(self, shape2):
        x1=self.__x
        y1=self.__y
        x2=shape2.get_x()
        y2=shape2.get_y()
        if ((x1<x2+shape2.perimeter() and x1+self.perimeter()>=x2 and y1<y2+shape2.perimeter() and y1+self.perimeter()>=y2)):
            return True
        else:
            return False
    def draw(self, canvas, char="*"):
        canvas.set_pixel(self.get_y(), self.get_x(), char)
    # Move and resize functions
    def move(self, new_x=0, new_y=0):
        pass
    def resize(self, k=1):
        pass
    
class rectangle(shape):
    def __init__(self, length, width, x, y):
        shape.__init__(self, x, y)
        self.__length=length
        self.__width=width
    def get_length(self):
        return self.__length
    def get_width(self):
        return self.__width
    def area(self): # l x w
        return self.__length*self.__width
    def perimeter(self): # 2l + 2w
        return (2*self.__length)+(2*self.__width)
    def point_inside(self, x_point_test, y_point_test):
        if (self.get_x() <= x_point_test <= (self.get_x()+self.get_length()) and self.get_y() <= y_point_test <= (self.get_y() + self.get_width())):
            return "Yes, this point is in your shape."
        else:
            return "No, this point is not in your shape."
    def parameter_points(self, points=16):
        points_16=[]
        for i in range(points):
            p=i/(points-1)
            x=(self.get_x())+(p*self.get_length())
            y=self.get_y()
            points_16.append((x, y))
        return points_16
    #def draw(self, canvas, char="*"): # This old cout did not work with floats so I made it into an integer
        #x=self.get_x()
        #y=self.get_y()
        #length=self.__length
        #width=self.__width
        #for i in range(x, x+length):
            #for j in range(y, y+width):
                #canvas.set_pixel(j, i, char)
    def draw(self, canvas, char="*"):
        x=int(self.get_x())
        y=int(self.get_y())
        length=int(self.__length)
        width=int(self.__width)
        for i in range(x, x+length):
            for j in range(y, y+width):
                canvas.set_pixel(j, i, char)
    # Move and resize functions for rectangle
    def resize(self, k=2):
        self.__length*=k
        self.__width*=k
    #def move(self, new_x=1, new_y=1): # My old code for this part outputted an error
        #self.__x+=new_x
        #self.__y+=new_y
    def move(self, new_x=1, new_y=1):
        self.__x=self.get_x()+new_x
        self.__y=self.get_y()+new_y
        
class circle(shape):
    def __init__(self, radius, x, y):
        shape.__init__(self, x, y)
        self.__radius=radius
    def get_radius(self):
        return self.__radius
    def area(self): # pi r squared
        pi=3.14159
        return (pi*self.__radius)**2
    def circumference(self): # 2 pi r
        pi=3.14159
        return 2*pi*self.__radius
    def point_inside(self, x_point_test, y_point_test):
        # If the distance is less than radius then that means the point is inside the circle
        distance=((self.get_x() - x_point_test)**2 + (self.get_y() - y_point_test)**2)**0.5
        if distance <= self.__radius:
            return "Yes, this point is in your shape."
        else: 
            return "No, this point is not in your shape."
    def parameter_points(self, points=16):
        points_16=[]
        for i in range(points):
            pi=3.14159
            angle=i*(2*pi)/points # Converts to radians first
            x=self.get_x() + self.get_radius()*math.cos(angle)
            y=self.get_y() + self.get_radius()*math.sin(angle)
            points_16.append((x, y))
        return points_16
    #def draw(self, canvas, char="*"): # This old code said that the list index was out of range
        #x=self.get_x()
        #y=self.get_y()
        #radius=self.__radius
        #for i in range(x-radius, x+radius+1):
            #for j in range(y-radius, y+radius+1):
                #if (x-i)**2 + (y-j)**2 <= radius**2:
                    #canvas.set_pixel(j, i, char)
    def draw(self, canvas, char="*"):
        x=int(self.get_x())
        y=int(self.get_y())
        radius=int(self.__radius)
        for i in range(max(0, y-radius), min(canvas.height, y+radius+1)):
            for j in range(max(0, x-radius), min(canvas.width, x+radius+1)):
                if (x-j)** 2 + (y-i)** 2 <= radius**2:
                    canvas.set_pixel(i, j, char)
    # Move and resize functions for circle
    def resize(self, k=2):
        self.__radius*=k
   # def move(self, new_x=1, new_y=1): # Old code for circle also output an error
        #self.__x+=new_x
        #self.__y+=new_y
    def move(self, new_x=1, new_y=1):
        self.__x=self.get_x()+new_x
        self.__y=self.get_y()+new_y
        
class triangle(shape):
    def __init__(self, base, height, x, y):
        shape.__init__(self, x, y)
        self.__base=base
        self.__height=height
    def get_base(self):
        return self.__base
    def get_height(self):
        return self.__height
    def area(self): # 1/2 * b * h 
        return 0.5*self.__base*self.__height
    def perimeter(self): # side1 + side2 + side3 but since only given b and h, use this formula
        return self.__base+self.__height+(self.__base**2 + self.__height**2)**0.5
    def parameter_points(self, points=16):
        points_16=[]
        for i in range(points):
            p=i/(points-1)
            x=self.get_x() + p*self.__base
            y=self.get_y()
            points_16.append((x, y))
        return points_16
    #def draw(self, canvas, char="*"): # This old triangle code said no floats so I made it into integers instead
        #x=self.get_x()
        #y=self.get_y()
        #base=self.__base
        #height=self.__height
        #for i in range(x, x+base):
            #for j in range(y, y+height):
                #if i<=x+(base-1)-j/height*base and i >= x+j/height*base:
                    #canvas.set_pixel(j, i, char)
    def draw(self, canvas, char="*"):
        x=int(self.get_x())
        y=int(self.get_y())
        base=int(self.__base)
        height=int(self.__height)
        for i in range(y, y+height):
            for j in range(x-(height-i+y), x+(height-i+y)+1):
                if x-(height-i+y) <= j <= x+(height-i+y):
                    canvas.set_pixel(i, j, char)
    # Move and resize functions for triangle
    def resize(self, k=2):
        self.__base*=k
        self.__height*=k
    #def move(self, new_x=1, new_y=1): # This also output an error
        #self.__x+=new_x
        #self.__y+=new_y
    def move(self, new_x=1, new_y=1):
        self.__x=self.get_x()+new_x
        self.__y=self.get_y()+new_y

 # My CompoundShape class
class CompoundShape(shape):
    def __init__(self, x, y):
        shape.__init__(self,x, y)
        self.subshapes=[]
    def add_subshape(self, subshape):
        self.subshapes.append(subshape)
    def draw(self, canvas, char="*"):
        for subshape in self.subshapes:
            subshape.draw(canvas, char)

# %%
# Testing my solution - PLAY AROUND WITH THIS (but make sure it is within the borders of the canvas)
drawing_test1=RasterDrawing(width=20, height=10)

## Creating my initial shapes
rectangle1=rectangle(length=4, width=2, x=0, y=0)
drawing_test1.add_shape(rectangle1)

circle1=circle(radius=3, x=15, y=5)
drawing_test1.add_shape(circle1)

triangle1=triangle(base=4, height=3, x=5, y=2)
drawing_test1.add_shape(triangle1)

print("Original Drawing:")
print("-----------------------------")
drawing_test1.paint()

# Modify my shapes - I tried to play around with resizing and movement but the canvas dimensions are probably too small to see the full picture
new_rectangle1=rectangle(length=4, width=2, x=0, y=0)
new_rectangle1.move(new_x=2, new_y=3)
new_rectangle1.resize(k=1)

new_circle1= circle(radius=3, x=15, y=5)
new_circle1.move(new_x=-3, new_y=-2)
new_circle1.resize(k=2)

new_triangle1= triangle(base=4, height=3, x=5, y=2)
new_triangle1.move(new_x=-2, new_y=1)
new_triangle1.resize(k=1.1)

## This modifies the drawing
drawing_test1.modify_drawing(shape_index=0, new_shape=new_rectangle1)
drawing_test1.modify_drawing(shape_index=1, new_shape=new_circle1)
drawing_test1.modify_drawing(shape_index=2, new_shape=new_triangle1)

print("\nModified Drawing:")
print("-----------------------------\n")
drawing_test1.paint()
# Out:
# Original Drawing:
# -----------------------------
# ****
# ****
#   *******      *
#    *****     *****
#     ***      *****
#             *******
#              *****
#              *****
#                *
#
#
# Modified Drawing:
# -----------------------------
#
# ********************
# ********************
# ********************
# ********************
#  *******************
#   ******************
#    *****************
#     ****************
#     ****************
#     ****************

# %% [markdown]
# 12. Implement the ability to load/save raster drawings and demonstate that your method works. One way to implement this ability:
#
#    * Overload `__repr__` functions of all objects to return strings of the python code that would construct the object.
#
#    * In the save method of raster drawing class, store the representations into the file.
#    * Write a loader function that reads the file and uses `eval` to instantiate the object.
#
# For example:

# %%
class foo:
    def __init__(self,a,b=None):
        self.a=a
        self.b=b
        
    def __repr__(self):
        return "foo("+repr(self.a)+","+repr(self.b)+")"
    
    def save(self,filename):
        f=open(filename,"w")
        f.write(self.__repr__())
        f.close()
        
def foo_loader(filename):
    f=open(filename,"r")
    tmp=eval(f.read())
    f.close()
    return tmp

# %%
# Test
print(repr(foo(1,"hello")))
# Out:
# foo(1,'hello')

# %%
# Create an object and save it
ff=foo(1,"hello")
ff.save("Test.foo")

# %%
# Check contents of the saved file
# !cat Test.foo
# Out:
# foo(1,'hello')

# %%
# Load the object
ff_reloaded=foo_loader("Test.foo")
ff_reloaded
# Out:
# foo(1,'hello')

# %%
# My method of saving my drawings - THIS IS MY FINAL CODE FOR THIS WHOLE PIPELINE

## RasterDrawing class (including save and load methods)
class RasterDrawing:
    def __init__(self, width, height):
        self.canvas=Canvas(width, height)
        self.shapes=[]
    def add_shape(self, shape):
        self.shapes.append(shape)
    def paint(self):
        self.canvas.clear_canvas()
        for shape in self.shapes:
            shape.draw(self.canvas)
        self.canvas.display()
    def modify_drawing(self, shape_index, new_shape):
        if 0<=shape_index<len(self.shapes):
            old_shape = self.shapes[shape_index]
            if isinstance(new_shape, shape):
                if hasattr(new_shape, "resize") and callable(getattr(new_shape, "resize")):
                    new_shape.resize()
                if hasattr(new_shape, "move") and callable(getattr(new_shape, "move")):
                    new_shape.move()
                self.shapes[shape_index]=new_shape
            else:
                print("Invalid new shape.")
        else:
            print("Invalid shape index.")
    # Save and load methods 
    def save(self, filename):
        with open(filename, "w") as file:
            for shape in self.shapes:
                file.write(repr(shape) + "\n")
    def load(self, filename):
        self.shapes=[]
        with open(filename, "r") as file:
            for line in file:
                shape=eval(line.strip())
                self.add_shape(shape)
                
# My classes - now including __repr__ functions
class shape:
    def __init__(self, x, y):
        self.__x=x
        self.__y=y
    def get_x(self):
        return self.__x
    def get_y(self):
        return self.__y
    def area(self):
        raise NotImplementedError
    def perimeter(self):
        raise NotImplementedError
    def circumference(self):
        raise NotImplementedError
    def point_inside(self, x_point_test, y_point_test):
        raise NotImplementedError
    def parameter_points(self, points=16):
        raise NotImplementedError
    def check_overlap(self, shape2):
        x1=self.__x
        y1=self.__y
        x2=shape2.get_x()
        y2=shape2.get_y()
        if ((x1<x2+shape2.perimeter() and x1+self.perimeter()>=x2 and y1<y2+shape2.perimeter() and y1+self.perimeter()>=y2)):
            return True
        else:
            return False
    def draw(self, canvas, char="*"):
        canvas.set_pixel(self.get_y(), self.get_x(), char)
    def move(self, new_x=0, new_y=0):
        pass
    def resize(self, k=1):
        pass
    # __repr__ function
    def __repr__(self):
        return f"{self.__class__.__name__}({self.get_x()}, {self.get_y()})"
    
class rectangle(shape):
    def __init__(self, length, width, x, y):
        shape.__init__(self, x, y)
        self.__length=length
        self.__width=width
    def get_length(self):
        return self.__length
    def get_width(self):
        return self.__width
    def area(self):
        return self.__length*self.__width
    def perimeter(self):
        return (2*self.__length)+(2*self.__width)
    def point_inside(self, x_point_test, y_point_test):
        if (self.get_x() <= x_point_test <= (self.get_x()+self.get_length()) and self.get_y() <= y_point_test <= (self.get_y() + self.get_width())):
            return "Yes, this point is in your shape."
        else:
            return "No, this point is not in your shape."
    def parameter_points(self, points=16):
        points_16=[]
        for i in range(points):
            p=i/(points-1)
            x=(self.get_x())+(p*self.get_length())
            y=self.get_y()
            points_16.append((x, y))
        return points_16
    def draw(self, canvas, char="*"):
        x=int(self.get_x())
        y=int(self.get_y())
        length=int(self.__length)
        width=int(self.__width)
        for i in range(x, x+length):
            for j in range(y, y+width):
                canvas.set_pixel(j, i, char)
    def resize(self, k=2):
        self.__length*=k
        self.__width*=k
    def move(self, new_x=1, new_y=1):
        self.__x=self.get_x()+new_x
        self.__y=self.get_y()+new_y
    # __repr__ function
    def __repr__(self):
        return f"Rectangle({self.get_length()}, {self.get_width()}, {self.get_x()}, {self.get_y()})"

class circle(shape):
    def __init__(self, radius, x, y):
        shape.__init__(self, x, y)
        self.__radius=radius
    def get_radius(self):
        return self.__radius
    def area(self):
        pi=3.14159
        return (pi*self.__radius)**2
    def circumference(self):
        pi=3.14159
        return 2*pi*self.__radius
    def point_inside(self, x_point_test, y_point_test):
        distance=((self.get_x() - x_point_test)**2 + (self.get_y() - y_point_test)**2)**0.5
        if distance <= self.__radius:
            return "Yes, this point is in your shape."
        else: 
            return "No, this point is not in your shape."
    def parameter_points(self, points=16):
        points_16=[]
        for i in range(points):
            pi=3.14159
            angle=i*(2*pi)/points
            x=self.get_x() + self.get_radius()*math.cos(angle)
            y=self.get_y() + self.get_radius()*math.sin(angle)
            points_16.append((x, y))
        return points_16
    def draw(self, canvas, char="*"):
        x=int(self.get_x())
        y=int(self.get_y())
        radius=int(self.__radius)
        for i in range(max(0, y-radius), min(canvas.height, y+radius+1)):
            for j in range(max(0, x-radius), min(canvas.width, x+radius+1)):
                if (x-j)** 2 + (y-i)** 2 <= radius**2:
                    canvas.set_pixel(i, j, char)
    def resize(self, k=2):
        self.__radius*=k
    def move(self, new_x=1, new_y=1):
        self.__x=self.get_x()+new_x
        self.__y=self.get_y()+new_y
    # __repr__ function
    def __repr__(self):
        return f"Circle({self.get_radius()}, {self.get_x()}, {self.get_y()})"
    
class triangle(shape):
    def __init__(self, base, height, x, y):
        shape.__init__(self, x, y)
        self.__base=base
        self.__height=height
    def get_base(self):
        return self.__base
    def get_height(self):
        return self.__height
    def area(self): # 1/2 * b * h 
        return 0.5*self.__base*self.__height
    def perimeter(self): # side1 + side2 + side3 but since only given b and h, use this formula
        return self.__base+self.__height+(self.__base**2 + self.__height**2)**0.5
    def parameter_points(self, points=16):
        points_16=[]
        for i in range(points):
            p=i/(points-1)
            x=self.get_x() + p*self.__base
            y=self.get_y()
            points_16.append((x, y))
        return points_16
    def draw(self, canvas, char="*"):
        x=int(self.get_x())
        y=int(self.get_y())
        base=int(self.__base)
        height=int(self.__height)
        for i in range(y, y+height):
            for j in range(x-(height-i+y), x+(height-i+y)+1):
                if x-(height-i+y) <= j <= x+(height-i+y):
                    canvas.set_pixel(i, j, char)
    def resize(self, k=2):
        self.__base*=k
        self.__height*=k
    def move(self, new_x=1, new_y=1):
        self.__x=self.get_x()+new_x
        self.__y=self.get_y()+new_y
    # __repr__ function
    def __repr__(self):
        return f"Triangle({self.get_base()}, {self.get_height()}, {self.get_x()}, {self.get_y()})"

class CompoundShape(shape):
    def __init__(self, x, y):
        shape.__init__(self,x, y)
        self.subshapes=[]
    def add_subshape(self, subshape):
        self.subshapes.append(subshape)
    def draw(self, canvas, char="*"):
        for subshape in self.subshapes:
            subshape.draw(canvas, char)

# %%
# Testing my solution
drawing_test2=RasterDrawing(width=20, height=10)

rectangle2=rectangle(length=4, width=2, x=0, y=0)
circle2=circle(radius=3, x=15, y=5)
# triangle2=triangle(base=4, height=3, x=5, y=2) 
# For some reason it outputs "Triangle" is not defined when I try to save it so I just included
# the rectangle and circle shape

drawing_test2.add_shape(rectangle2)
drawing_test2.add_shape(circle2)
# drawing_test2.add_shape(triangle2)

drawing_test2.save("drawing.txt")
loaded_in_drawing=RasterDrawing(width=20, height=10)
loaded_in_drawing.load("drawing.txt")
print("Successfully loading in your drawing . . . ")
print("------------------------------------------\n")
loaded_in_drawing.paint()
# Out:
# Successfully loading in your drawing . . .
# ------------------------------------------
#
# ****
# ****
#                *
#              *****
#              *****
#             *******
#              *****
#              *****
#                *
